# %% [markdown]
# # Using `aiproteomics` to build a spectral library
#
# In this demo notebook we will see how to use the `aiproteomics` infrastructure to wrap a prediction model (e.g. MSMS) and generate spectral library entries.
#
# First, we import the `aiproteomics` library, and check the version. This can be helpful for debugging by making sure you are looking at the correct documentation version.

# %%
import aiproteomics
print(aiproteomics.__VERSION__)
# Out:
# 0.6.0

# %% [markdown]
# ## Creating an `AIProteomicsModel`
#
# To create an `AIProteomicsModel`, we need three things:
#
# * A `SequenceMapper` that knows how to map the string representation of a peptide sequence (e.g. _AEEDEILNRS(UniMod:21)PR_ ) to an integer array suitable for input to the AI model.
# * A `ModelParams` instance, that defines how the output of the AI model should be interpreted.
# * The AI model itself (currently a `tensorflow` model, but could be extended easily to include `pytorch` models too)
#
# Essentially, the `SequenceMapper` is used to prepare input for the prediction model, and the `ModelParams` is used to interpret and post-process the output of the prediction model.

# %% [markdown]
# #### Making a `SequenceMapper`
#
# All (deep learning) prediction models used with `aiproteomics` are assumed to take a peptide sequence (in some form) as input. A `SequenceMapper` is responsible for pre-processing the string representation of a peptide sequence (including `UniMod` modifications) into a format that is ready to be given straight to the model.
#
# Currently, this means that there are three parameters for creating a sequence mapper for your model:
# * `min_seq_len` and `max_seq_len`, to only accept sequences in a length range appropriate for the model
# * `mapping`, a `Dict` that maps each amino acid (and modification, if applicable) to a particular integer value.
#
# Of course, there are many ways of mapping the sequence to an array of integers. `aiproteomics` offers two ready to go: `PHOSPHO_MAPPING` which handles most amino acids as well as several modifications (including phosphorylation), and `PROSIT_MAPPING` which uses the same mapping as for the original 2019 Prosit MSMS model.
#
# The mapping implementation is relatively simple (see the module code `aiproteomics.core.sequence`), essentially just a dictionary, so it is possible to make your own such mapping and use that to initialize a `SequenceMapper` instead.
#
# Below, we choose to accept only peptides in the range 7 to 50 amino acids, and the `PHOSPHO_MAPPING`.

# %%
from aiproteomics.core.sequence import SequenceMapper, PHOSPHO_MAPPING

# Choose what sequence mapping you want to use
seqmap = SequenceMapper(min_seq_len=7, max_seq_len=50, mapping=PHOSPHO_MAPPING)

# %% [markdown]
# You can see the contents of this `SequenceMapper` by printing it out:

# %%
seqmap
# Out:
# SequenceMapper(min_seq_len=7, max_seq_len=50, mapping=SequenceMapping(description='Mapping for the phospho model', aa_int_map={' ': 0, 'A': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'I': 8, 'K': 9, 'L': 10, 'M': 11, 'N': 12, 'P': 13, 'Q': 14, 'R': 15, 'S': 16, 'T': 17, 'V': 18, 'W': 19, 'Y': 20, '1': 21, '2': 22, '3': 23, '4': 24, '*': 25}, aa_mod_map={'M(UniMod:35)': '1', 'S(UniMod:21)': '2', 'T(UniMod:21)': '3', 'Y(UniMod:21)': '4', '(UniMod:1)': '*', 'C(UniMod:4)': 'C'}))

# %% [markdown]
# In the above you should see exactly how each amino acid is mapped to an integer, as well as how modifications are handled.

# %% [markdown]
# #### Defining the `ModelParams` for your model
#
# We now must define what kind of prediction model we will use. In practice, this is mainly used for post-processing the model output, since it determines how to interpret the output layer(s).
#
# In the following we will show this for the most complex model type, a fragmentation (MSMS) model. A `ModelParamsMSMS` object can be constructed with the following info:
# * `seq_len`: the maximum length of a peptide sequence to the model (needed for determining how many breakage points and therefore possible fragments)
# * `ions`: a list of the ion types supported by the model. It is common to use just 'y' and 'b', but more can be specified (e.g. 'a').
# * `max_charge`: the maximum charge on any fragment. If set to 3, for example, then only fragments of max 3+ charge will appear in the output.
# * `neutral_losses`: this can be `H2O`, `NH3` or (for phosphoproteomics) `H3PO4`
#
# Note that all the above choices determine the possible fragments and therefore the size of the output layer of the AI model (in `aiproteomics` we currently support models that predict one intensity value per possible peptide fragment).

# %%
from aiproteomics.core.modeltypes import ModelParamsMSMS

# Choose your model type (msms) and the parameters for its output
params = ModelParamsMSMS(seq_len=50, ions=['y','b'], max_charge=2, neutral_losses=['', 'H3PO4'])

# %% [markdown]
# If you wish to check what fragments are defined by your `ModelParamsMSMS` object, and the ordering they will have in the output layer, you can print out the `.fragments` member:

# %%
params.fragments
# Out:
# array([Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=1, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=1, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=1, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=1, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=2, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=2, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=2, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=2, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=3, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=3, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=3, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=3, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=4, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=4, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=4, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=4, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=5, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=5, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=5, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=5, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=6, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=6, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=6, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=6, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=7, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=7, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=7, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=7, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=8, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=8, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=8, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=8, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=9, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=9, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=9, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=9, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=10, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=10, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=10, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=10, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=11, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=11, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=11, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=11, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=12, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=12, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=12, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=12, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=13, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=13, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=13, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=13, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=14, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=14, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=14, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=14, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=15, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=15, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=15, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=15, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=16, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=16, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=16, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=16, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=17, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=17, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=17, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=17, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=18, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=18, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=18, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=18, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=19, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=19, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=19, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=19, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=20, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=20, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=20, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=20, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=21, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=21, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=21, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=21, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=22, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=22, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=22, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=22, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=23, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=23, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=23, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=23, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=24, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=24, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=24, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=24, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=25, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=25, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=25, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=25, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=26, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=26, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=26, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=26, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=27, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=27, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=27, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=27, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=28, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=28, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=28, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=28, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=29, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=29, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=29, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=29, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=30, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=30, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=30, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=30, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=31, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=31, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=31, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=31, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=32, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=32, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=32, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=32, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=33, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=33, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=33, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=33, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=34, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=34, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=34, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=34, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=35, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=35, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=35, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=35, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=36, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=36, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=36, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=36, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=37, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=37, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=37, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=37, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=38, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=38, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=38, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=38, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=39, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=39, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=39, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=39, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=40, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=40, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=40, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=40, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=41, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=41, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=41, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=41, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=42, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=42, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=42, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=42, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=43, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=43, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=43, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=43, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=44, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=44, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=44, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=44, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=45, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=45, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=45, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=45, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=46, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=46, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=46, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=46, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=47, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=47, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=47, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=47, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=48, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=48, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=48, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=48, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=49, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=49, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=49, fragment_loss_type=''),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=49, fragment_loss_type=''),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=1, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=1, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=1, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=1, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=2, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=2, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=2, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=2, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=3, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=3, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=3, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=3, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=4, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=4, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=4, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=4, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=5, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=5, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=5, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=5, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=6, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=6, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=6, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=6, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=7, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=7, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=7, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=7, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=8, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=8, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=8, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=8, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=9, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=9, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=9, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=9, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=10, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=10, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=10, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=10, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=11, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=11, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=11, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=11, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=12, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=12, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=12, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=12, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=13, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=13, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=13, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=13, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=14, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=14, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=14, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=14, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=15, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=15, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=15, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=15, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=16, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=16, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=16, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=16, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=17, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=17, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=17, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=17, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=18, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=18, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=18, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=18, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=19, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=19, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=19, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=19, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=20, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=20, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=20, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=20, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=21, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=21, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=21, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=21, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=22, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=22, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=22, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=22, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=23, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=23, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=23, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=23, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=24, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=24, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=24, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=24, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=25, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=25, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=25, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=25, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=26, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=26, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=26, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=26, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=27, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=27, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=27, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=27, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=28, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=28, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=28, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=28, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=29, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=29, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=29, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=29, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=30, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=30, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=30, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=30, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=31, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=31, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=31, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=31, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=32, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=32, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=32, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=32, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=33, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=33, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=33, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=33, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=34, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=34, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=34, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=34, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=35, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=35, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=35, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=35, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=36, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=36, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=36, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=36, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=37, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=37, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=37, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=37, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=38, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=38, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=38, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=38, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=39, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=39, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=39, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=39, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=40, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=40, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=40, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=40, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=41, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=41, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=41, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=41, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=42, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=42, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=42, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=42, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=43, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=43, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=43, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=43, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=44, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=44, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=44, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=44, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=45, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=45, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=45, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=45, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=46, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=46, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=46, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=46, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=47, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=47, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=47, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=47, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=48, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=48, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=48, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=48, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=1, fragment_series_number=49, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='y', fragment_charge=2, fragment_series_number=49, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=1, fragment_series_number=49, fragment_loss_type='H3PO4'),
#        Fragment(fragment_type='b', fragment_charge=2, fragment_series_number=49, fragment_loss_type='H3PO4')],
#       dtype=object)

# %% [markdown]
# Checking the number of fragments will show you the (expected) length of your model's output layer:

# %%
len(params.fragments)
# Out:
# 392

# %% [markdown]
# #### Create a (`tensorflow`) model
#
# Finally, having configured the infrastructure for input (sequence mapping) and output (model params) of the AI model, we now need to provide the model itself. In the following we just use a "dummy" model with the input/output layers expected of an MSMS modl. In practice you can use your own (new) model here, or generate a new one with the functions provided in `aiproteomics.models`.
#
# Currently only tensorflow models are directly supported but pytorch models could be handled in the code without too much work.

# %%
from aiproteomics.models.dummy_models import generate_dummy_msms_model

# Make a compatible NN model
nn_model, creation_meta = generate_dummy_msms_model(
    params=params,
    num_layers=6,
    num_heads=8,
    d_ff=2048,
    dropout_rate=0.1
)

# %% [markdown]
# #### Build your `AIProteomicsModel`
#
# Finally, with the above three objects, we can now build our `AIProteomicsModel`. This is really just a convenient class that keeps all relevant parts of the model together, and also provides utility functionality such as saving the model to a directory, or reloading an existing model.

# %%
from aiproteomics.core.modeltypes import AIProteomicsModel

# Build the model
msmsmodel = AIProteomicsModel(seq_map=seqmap, model_params=params, nn_model=nn_model, nn_model_creation_metadata=creation_meta)

# %% [markdown]
# In the following, we can print out the `AIProteomicsModel` we have created, which should contain all the information required to process input and output of the given MSMS prediction model:

# %%
from pprint import pprint
pprint(msmsmodel)
# Out:
# AIProteomicsModel(seq_map=SequenceMapper(min_seq_len=7,
#                                          max_seq_len=50,
#                                          mapping=SequenceMapping(description='Mapping '
#                                                                              'for '
#                                                                              'the '
#                                                                              'phospho '
#                                                                              'model',
#                                                                  aa_int_map={' ': 0,
#                                                                              '*': 25,
#                                                                              '1': 21,
#                                                                              '2': 22,
#                                                                              '3': 23,
#                                                                              '4': 24,
#                                                                              'A': 1,
#                                                                              'C': 2,
#                                                                              'D': 3,
#                                                                              'E': 4,
#                                                                              'F': 5,
#                                                                              'G': 6,
#                                                                              'H': 7,
#                                                                              'I': 8,
#                                                                              'K': 9,
#                                                                              'L': 10,
#                                                                              'M': 11,
#                                                                              'N': 12,
#                                                                              'P': 13,
#                                                                              'Q': 14,
#                                                                              'R': 15,
#                                                                              'S': 16,
#                                                                              'T': 17,
#                                                                              'V': 18,
#                                                                              'W': 19,
#                                                                              'Y': 20},
#                                                                  aa_mod_map={'(UniMod:1)': '*',
#                                                                              'C(UniMod:4)': 'C',
#                                                                              'M(UniMod:35)': '1',
#                                                                              'S(UniMod:21)': '2',
#                                                                              'T(UniMod:21)': '3',
#                                                                              'Y(UniMod:21)': '4'})),
#                   model_params=ModelParamsMSMS(seq_len=50,
#                                                ions=['y', 'b'],
#                                                max_charge=2,
#                                                neutral_losses=['', 'H3PO4']),
#                   nn_model=<keras.src.engine.functional.Functional object at 0x7d87c0119c00>,
#                   nn_model_creation_metadata={'args': {'d_ff': 2048,
#                                                        'dropout_rate': 0.1,
#                                                        'num_heads': 8,
#                                                        'num_layers': 6},
#                                               'name': 'generate_dummy_msms_model'})

# %% [markdown]
# ### Saving and reloading the `AIProteomicsModel`

# %% [markdown]
# A useful feature of an `AIProteomicsModel` is the ability to save it to a directory. This means it can be reloaded into python later (for example, in another script)

# %%
# Save the model
msmsmodel.to_dir("testmodelfrag/", overwrite=True)

# Load the model back in as a new AIProteomicsModel instance
reloaded_msms = AIProteomicsModel.from_dir("testmodelfrag/")

# Check what's inside
pprint(reloaded_msms)
# Out:
# WARNING:absl:Skipping variable loading for optimizer 'Adam', because it has 9 variables whereas the saved optimizer has 1 variables.
# AIProteomicsModel(seq_map=SequenceMapper(min_seq_len=7,
#                                          max_seq_len=50,
#                                          mapping=SequenceMapping(description='Mapping '
#                                                                              'for '
#                                                                              'the '
#                                                                              'phospho '
#                                                                              'model',
#                                                                  aa_int_map={' ': 0,
#                                                                              '*': 25,
#                                                                              '1': 21,
#                                                                              '2': 22,
#                                                                              '3': 23,
#                                                                              '4': 24,
#                                                                              'A': 1,
#                                                                              'C': 2,
#                                                                              'D': 3,
#                                                                              'E': 4,
#                                                                              'F': 5,
#                                                                              'G': 6,
#                                                                              'H': 7,
#                                                                              'I': 8,
#                                                                              'K': 9,
#                                                                              'L': 10,
#                                                                              'M': 11,
#                                                                              'N': 12,
#                                                                              'P': 13,
#                                                                              'Q': 14,
#                                                                              'R': 15,
#                                                                              'S': 16,
#                                                                              'T': 17,
#                                                                              'V': 18,
#                                                                              'W': 19,
#                                                                              'Y': 20},
#                                                                  aa_mod_map={'(UniMod:1)': '*',
#                                                                              'C(UniMod:4)': 'C',
#                                                                              'M(UniMod:35)': '1',
#                                                                              'S(UniMod:21)': '2',
#                                                                              'T(UniMod:21)': '3',
#                                                                              'Y(UniMod:21)': '4'})),
#                   model_params=ModelParamsMSMS(seq_len=50,
#                                                ions=['y', 'b'],
#                                                max_charge=2,
#                                                neutral_losses=['', 'H3PO4']),
#                   nn_model=<keras.src.engine.functional.Functional object at 0x7d87bab52e90>,
#                   nn_model_creation_metadata={'args': {'d_ff': 2048,
#                                                        'dropout_rate': 0.1,
#                                                        'num_heads': 8,
#                                                        'num_layers': 6},
#                                               'name': 'generate_dummy_msms_model'})

# %% [markdown]
# ### Making an AIProteomicsModel for iRT and CCS
#
# Briefly, the following shows that retention time and ion mobility models may be similarly made into `AIProteomics` models:

# %%
from aiproteomics.core.modeltypes import ModelParamsRT, ModelParamsCCS
from aiproteomics.models.dummy_models import generate_dummy_iRT_model, generate_dummy_ccs_model

# Try making a phospho-style iRT model
params = ModelParamsRT(seq_len=50, iRT_rescaling_mean=101.11514, iRT_rescaling_var=46.5882)
nn_model, creation_meta = generate_dummy_iRT_model(
    params=params,
    num_layers=6,
    num_heads=8,
    d_ff=2048,
    dropout_rate=0.1
)
rtmodel = AIProteomicsModel(seq_map=seqmap, model_params=params, nn_model=nn_model, nn_model_creation_metadata=creation_meta)

# Try making a phospho-style ion mobility model
params = ModelParamsCCS(seq_len=50)
nn_model, creation_meta = generate_dummy_ccs_model(
    params=params,
    num_layers=6,
    num_heads=8,
    d_ff=2048,
    dropout_rate=0.1
)
ccsmodel = AIProteomicsModel(seq_map=seqmap, model_params=params, nn_model=nn_model, nn_model_creation_metadata=creation_meta)

# %% [markdown]
# ### Use the `AIProteomicsModel` to generate a spectral library
# Now we can use the models to generate a spectral library for a given list of input peptides (in `peptides_to_predict.tsv`).

# %%
import pandas as pd

input_peptides = pd.read_csv('peptides_to_predict.tsv', sep='\t')

input_peptides
# Out:
#     peptide  charge
# 0  STADAADA       1
# 1  ADSDDDDD       1
# 2  DDDDDDDD       2

# %%
from aiproteomics.core.utils import build_spectral_library

speclib_df = build_spectral_library(input_peptides, msms=msmsmodel, rt=rtmodel, ccs=ccsmodel)

speclib_df
# Out:
# 1/1 [==============================] - 0s 300ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
#     index  PrecursorMz   ProductMz    Annotation ProteinId GeneName  \
# 0       0   721.299866   88.039307            b1      None     None
# 1       1   721.299866  260.124084            b3      None     None
# 2       2   721.299866  375.151031            b4      None     None
# 3       3   721.299866  462.183075            y5      None     None
# 4       4   721.299866  517.225281            b6      None     None
# 5       5   721.299866   91.110085      b2-H3PO4      None     None
# 6       6   721.299866  178.142120      y3-H3PO4      None     None
# 7       7   721.299866  162.147202      b3-H3PO4      None     None
# 8       8   721.299866  435.243286      y6-H3PO4      None     None
# 9       9   721.299866  419.248383      b6-H3PO4      None     None
# 10     10   721.299866  216.042999            pY      None     None
# 11      0   867.248657   72.044388            b1      None     None
# 12      1   867.248657  681.184570            y6      None     None
# 13      2   867.248657  619.184204            b6      None     None
# 14      3   867.248657  -25.932505      b1-H3PO4      None     None
# 15      4   867.248657  151.094833      y2-H3PO4      None     None
# 16      5   867.248657  266.121765      y3-H3PO4      None     None
# 17      6   867.248657  381.148712      y4-H3PO4      None     None
# 18      7   867.248657  291.153412      b4-H3PO4      None     None
# 19      8   867.248657  521.207275      b6-H3PO4      None     None
# 20      9   867.248657  698.234619      y7-H3PO4      None     None
# 21     10   867.248657  216.042999            pY      None     None
# 22      0   470.120331  297.579926        y5(2+)      None     None
# 23      1   470.120331  133.084274      b2-H3PO4      None     None
# 24      2   470.120331  191.078003  y4(2+)-H3PO4      None     None
# 25      3   470.120331  248.591461  y5(2+)-H3PO4      None     None
# 26      4   470.120331  611.202576      y6-H3PO4      None     None
# 27      5   470.120331  306.104950  y6(2+)-H3PO4      None     None
# 28      6   470.120331  216.042999            pY      None     None
#
#    PeptideSequence ModifiedPeptideSequence  PrecursorCharge  LibraryIntensity  \
# 0         STADAADA                STADAADA                1          1.131502
# 1         STADAADA                STADAADA                1          1.014848
# 2         STADAADA                STADAADA                1          1.587804
# 3         STADAADA                STADAADA                1          0.944723
# 4         STADAADA                STADAADA                1          2.516924
# 5         STADAADA                STADAADA                1          3.544521
# 6         STADAADA                STADAADA                1          1.795422
# 7         STADAADA                STADAADA                1          2.130765
# 8         STADAADA                STADAADA                1          1.329103
# 9         STADAADA                STADAADA                1          1.953735
# 10        STADAADA                STADAADA                1          0.896340
# 11        ADSDDDDD                ADSDDDDD                1          0.949504
# 12        ADSDDDDD                ADSDDDDD                1          1.257418
# 13        ADSDDDDD                ADSDDDDD                1          1.850863
# 14        ADSDDDDD                ADSDDDDD                1          2.484853
# 15        ADSDDDDD                ADSDDDDD                1          0.955866
# 16        ADSDDDDD                ADSDDDDD                1          0.987596
# 17        ADSDDDDD                ADSDDDDD                1          0.953368
# 18        ADSDDDDD                ADSDDDDD                1          0.818393
# 19        ADSDDDDD                ADSDDDDD                1          1.532478
# 20        ADSDDDDD                ADSDDDDD                1          1.679662
# 21        ADSDDDDD                ADSDDDDD                1          4.142801
# 22        DDDDDDDD                DDDDDDDD                2          1.071490
# 23        DDDDDDDD                DDDDDDDD                2          0.855010
# 24        DDDDDDDD                DDDDDDDD                2          0.821463
# 25        DDDDDDDD                DDDDDDDD                2          1.265525
# 26        DDDDDDDD                DDDDDDDD                2          0.889791
# 27        DDDDDDDD                DDDDDDDD                2          0.996032
# 28        DDDDDDDD                DDDDDDDD                2          1.371844
#
#     NormalizedRetentionTime  PrecursorIonMobility FragmentType  \
# 0                  0.032277             -2.011733            b
# 1                  0.032277             -2.011733            b
# 2                  0.032277             -2.011733            b
# 3                  0.032277             -2.011733            y
# 4                  0.032277             -2.011733            b
# 5                  0.032277             -2.011733            b
# 6                  0.032277             -2.011733            y
# 7                  0.032277             -2.011733            b
# 8                  0.032277             -2.011733            y
# 9                  0.032277             -2.011733            b
# 10                 0.032277             -2.011733           pY
# 11                -1.150322             -0.932366            b
# 12                -1.150322             -0.932366            y
# 13                -1.150322             -0.932366            b
# 14                -1.150322             -0.932366            b
# 15                -1.150322             -0.932366            y
# 16                -1.150322             -0.932366            y
# 17                -1.150322             -0.932366            y
# 18                -1.150322             -0.932366            b
# 19                -1.150322             -0.932366            b
# 20                -1.150322             -0.932366            y
# 21                -1.150322             -0.932366           pY
# 22                -0.017313             -0.167467            y
# 23                -0.017313             -0.167467            b
# 24                -0.017313             -0.167467            y
# 25                -0.017313             -0.167467            y
# 26                -0.017313             -0.167467            y
# 27                -0.017313             -0.167467            y
# 28                -0.017313             -0.167467           pY
#
#     FragmentCharge  FragmentSeriesNumber FragmentLossType
# 0                1                     1
# 1                1                     3
# 2                1                     4
# 3                1                     5
# 4                1                     6
# 5                1                     2            H3PO4
# 6                1                     3            H3PO4
# 7                1                     3            H3PO4
# 8                1                     6            H3PO4
# 9                1                     6            H3PO4
# 10               0                     0
# 11               1                     1
# 12               1                     6
# 13               1                     6
# 14               1                     1            H3PO4
# 15               1                     2            H3PO4
# 16               1                     3            H3PO4
# 17               1                     4            H3PO4
# 18               1                     4            H3PO4
# 19               1                     6            H3PO4
# 20               1                     7            H3PO4
# 21               0                     0
# 22               2                     5
# 23               1                     2            H3PO4
# 24               2                     4            H3PO4
# 25               2                     5            H3PO4
# 26               1                     6            H3PO4
# 27               2                     6            H3PO4
# 28               0                     0

# %% [markdown]
# Finally, you can output the generated spectral library to `.tsv` format:

# %%
speclib_df.to_csv('speclib.tsv', sep='\t')

# %% [markdown]
# Or, more efficiently, to `parquet`:

# %%
speclib_df.to_parquet('speclibe.parquet')
